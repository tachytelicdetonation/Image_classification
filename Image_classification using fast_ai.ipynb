# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
import os

# %%
bs = 16

# %%
data_dir = '../input/car_data/car_data/'
path = Path(data_dir)

# %%
tfms = get_transforms(do_flip = True)
data = (ImageList.from_folder(path)
        .split_by_rand_pct()
        .label_from_folder()
        .transform(tfms, size=224)
        .databunch()).normalize(imagenet_stats)

# %%
data.show_batch(rows = 3,figsize = (9,5))

# %%
learn = cnn_learner(data,models.resnet50,metrics = accuracy,model_dir = '/tmp/model/')

# %%
print(data.classes)
len(data.classes),data.c

# %%
learn.model

# %%
learn.fit_one_cycle(4)

# %%
learn.save('model1')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
interp.most_confused(min_val=2)

# %%
learn.load('model1');

# %%
learn.lr_find(num_it = 200)

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(10, max_lr=slice(1e-6,1e-4))

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)

# %%
interp.plot_top_losses(9, size=(9,5))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
